# %%
#export
TEST = 'Test'

# %%
# !python notebook2script.py 00_exports.ipynb
# Out:
# Converted 00_exports.ipynb to exp/nb_00.py

# %%
# !ls
# Out:
# 00_exports.ipynb  exp		      run_notebook.py
# 01_matmul.ipynb   notebook2script.py  t.py

# %%
# !cat ./exp/nb_00.py
# Out:
# #################################################
# ### THIS FILE WAS AUTOGENERATED! DO NOT EDIT! ###
# #################################################
# # file to edit: dev_nb/00_exports.ipynb
#
# TEST = 'Test'

# %%
import json

d = json.load(open('00_exports.ipynb','r'))

# %%
d['cells'][-2]['source']
# Out:
# ['import json\n', '\n', "d = json.load(open('00_exports.ipynb','r'))"]
